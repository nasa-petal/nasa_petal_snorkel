# %% [markdown]
# ### Imports

# %%
import pandas as pd
import itertools
from snorkel.labeling import labeling_function
from snorkel.labeling import LabelingFunction
from snorkel.labeling.model import LabelModel
from snorkel.labeling import PandasLFApplier
import snorkel_lfsmall_2

# %% [markdown]
# ### Data and Labeling Function Loading

# %%
# Read in data
# df_train = pd.read_json(r"C:\Users\ARalevski\Documents\Petal\data-collection-and-prep\new_golden.json")
df_train = pd.read_csv(r"C:\Users\ARalevski\Documents\Petal\Snorkel-PeTaL\labeled_data.csv")
df_train = df_train.fillna("")


# List labeling functions
lfs = []
new_labels = []
for method in dir(snorkel_lfsmall_2):
    if "lf_" in method:
        lfs.append(getattr(snorkel_lfsmall_2, method))
        new_labels.append(method[3:])
    elif "keyword_" in method:
        lfs.append(getattr(snorkel_lfsmall_2, method))
        new_labels.append(method[8:])

len(lfs)
# Out:
# 15

# %%
print(lfs)
# Out:
# [<function keyword_lookup at 0x00000153C5813820>, LabelingFunction lf_protect_from_animals, Preprocessors: [], LabelingFunction lf_protect_from_chemicals, Preprocessors: [], LabelingFunction lf_protect_from_excess_liquids, Preprocessors: [], LabelingFunction lf_protect_from_fire, Preprocessors: [], LabelingFunction lf_protect_from_fungi, Preprocessors: [], LabelingFunction lf_protect_from_ice, Preprocessors: [], LabelingFunction lf_protect_from_light, Preprocessors: [], LabelingFunction lf_protect_from_microbes, Preprocessors: [], LabelingFunction lf_protect_from_plants, Preprocessors: [], LabelingFunction lf_protect_from_radiation, Preprocessors: [], LabelingFunction lf_protect_from_solids, Preprocessors: [], LabelingFunction lf_protect_from_temperature, Preprocessors: [], LabelingFunction lf_protect_from_wind, Preprocessors: [], <function make_keyword_lf at 0x00000153C5813D30>]

# %% [markdown]
# Updated Function Enumerated CSV

# %%
form = pd.DataFrame()
new_rows = []
count = 0
for row in lfs:
    new_rows.append({"function": row.name[3:], "function_enumerated": count})
    count += 1
form = pd.concat([form, pd.DataFrame(new_rows)])

# %%
# The notebook should be restarted if you change this file
form.to_csv(r"C:\Users\ARalevski\Documents\Petal\Snorkel-PeTaL\formatted_enums.csv", index=False)

# %% [markdown]
# ### Apply Labeling Functions

# %%
# Apply the LFs to the unlabled training data
applier = PandasLFApplier(lfs)
l_train = applier.apply(df_train)
# Out:
# 100%|██████████| 1430/1430 [00:04<00:00, 339.72it/s]

# %%
l_train
# Out:
# array([[10, 23, 15, ..., 14, 19, 18],
#        [10, 23, 15, ..., 14, 19, 18],
#        [10, 23, 15, ..., 14, 19, 18],
#        ...,
#        [10, 23, 15, ..., 14, 19, 18],
#        [10, 23, 15, ..., 14, 19, 18],
#        [10, 23, 15, ..., 14, 19, 18]])

# %%
len(lfs)
# Out:
# 13

# %% [markdown]
# ### Train Model

# %%
# Train the label model and compute the training labels
# Cardinality = number of classes
label_model = LabelModel(cardinality=25, verbose=True)

# %%
label_model.fit(l_train, n_epochs=500, log_freq=50, seed=123)

# %% [markdown]
# ### Predict and Display Results

# %%
df_train["label"] = label_model.predict(L=l_train, tie_break_policy="abstain")

# %%
# Number of unique labels, if this is only 1, every prediction was most likely abstained.
df_train["label"].nunique()
# Out:
# 1

# %%
# Append Probabilities of labels to each record
probs = label_model.predict_proba(l_train)
for prob in probs:
    count = 0
    for name in lfs:
        df_train[name.name] = prob[count]
        count += 1
        # history.append(name)

# %%
# Out:
#                           doi  \
# 0         10.1098/rsos.140322
# 1      10.1098/rsbl.2004.0269
# 2     10.1644/08-MAMM-A-108.1
# 3            10.1038/35099670
# 4          10.1242/jeb.036871
# ...                       ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                                     url  \
# 0     https://royalsocietypublishing.org/doi/10.1098...
# 1     https://royalsocietypublishing.org/doi/10.1098...
# 2     https://academic.oup.com/jmammal/article/90/2/...
# 3              https://www.nature.com/articles/35099670
# 4          https://jeb.biologists.org/content/213/2/288
# ...                                                 ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                                   title  \
# 0     Impact behaviour of freeze-dried and fresh pom...
# 1     Distribution of unique red feather pigments in...
# 2     Home Ranges, Movement, and Den Use in Long-Bea...
# 3                     Energy saving in flight formation
# 4     Correlation between aquaporin and water permea...
# ...                                                 ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                                abstract  \
# 0     Pomelos (Citrus maxima) are known for their th...
# 1     In many birds, red, orange and yellow feathers...
# 2     Abstract Long-beaked echidnas (Zaglossus), whi...
# 3     Many species of large bird fly together in for...
# 4     SUMMARY The ventral pelvic skin of the tree fr...
# ...                                                 ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                           full_doc_link is_open_access  \
# 0     https://royalsocietypublishing.org/doi/10.1098...           True
# 1     https://royalsocietypublishing.org/doi/10.1098...           True
# 2     https://academic.oup.com//jmammal/article-pdf/...          False
# 3          https://www.nature.com/articles/35099670.pdf           True
# 4     https://journals.biologists.com/jeb/article-pd...           True
# ...                                                 ...            ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                           label_level_1  \
# 0                     ['Maintain structural integrity']
# 1     ['Sense send or process information', 'Change ...
# 2            ['Process resources', 'Protect from harm']
# 3             ['Move', 'Maintain ecological community']
# 4                                 ['Process resources']
# ...                                                 ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                           label_level_2  \
# 0     ['Manage structural forces', 'Prevent structur...
# 1                      ['Send signals', 'Modify color']
# 2     ['Distribute resources', 'Protect from non-liv...
# 3                                  ['Passive movement']
# 4     ['Capture resources', 'Absorb and/or filter re...
# ...                                                 ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                           label_level_3  \
# 0         ['Manage impact', 'Prevent fracture/rupture']
# 1     ['Send light signals in the visible spectrum',...
# 2           ['Distribute gases', 'Protect from solids']
# 3     ['Coordinate by self-organization', 'Passively...
# 4                      ['Absorb and/or filter liquids']
# ...                                                 ...
# 1425
# 1426
# 1427
# 1428
# 1429
#
#                                                 journal  ...  \
# 0     ['Advanced Engineering Materials', 'Royal Soci...  ...
# 1                                   ['Biology Letters']  ...
# 2     ['Journal of Experimental Biology (JEB)', 'Jou...  ...
# 3                                            ['Nature']  ...
# 4     ['Journal of Experimental Biology (JEB)', 'End...  ...
# ...                                                 ...  ...
# 1425                                                     ...
# 1426                                                     ...
# 1427                                                     ...
# 1428                                                     ...
# 1429                                                     ...
#
#      lf_protect_from_harm3 lf_protect_from_ice  lf_protect_from_light  \
# 0                 0.038205            0.066567               0.066567
# 1                 0.038205            0.066567               0.066567
# 2                 0.038205            0.066567               0.066567
# 3                 0.038205            0.066567               0.066567
# 4                 0.038205            0.066567               0.066567
# ...                    ...                 ...                    ...
# 1425              0.038205            0.066567               0.066567
# 1426              0.038205            0.066567               0.066567
# 1427              0.038205            0.066567               0.066567
# 1428              0.038205            0.066567               0.066567
# 1429              0.038205            0.066567               0.066567
#
#       lf_protect_from_loss_liquids  lf_protect_from_microbes  \
# 0                         0.066567                  0.066567
# 1                         0.066567                  0.066567
# 2                         0.066567                  0.066567
# 3                         0.066567                  0.066567
# 4                         0.066567                  0.066567
# ...                            ...                       ...
# 1425                      0.066567                  0.066567
# 1426                      0.066567                  0.066567
# 1427                      0.066567                  0.066567
# 1428                      0.066567                  0.066567
# 1429                      0.066567                  0.066567
#
#       lf_protect_from_plants  lf_protect_from_radiation  \
# 0                   0.066567                   0.066567
# 1                   0.066567                   0.066567
# 2                   0.066567                   0.066567
# 3                   0.066567                   0.066567
# 4                   0.066567                   0.066567
# ...                      ...                        ...
# 1425                0.066567                   0.066567
# 1426                0.066567                   0.066567
# 1427                0.066567                   0.066567
# 1428                0.066567                   0.066567
# 1429                0.066567                   0.066567
#
#       lf_protect_from_solids  lf_protect_from_temperature  \
# 0                   0.066567                     0.066567
# 1                   0.066567                     0.066567
# 2                   0.066567                     0.066567
# 3                   0.066567                     0.066567
# 4                   0.066567                     0.066567
# ...                      ...                          ...
# 1425                0.066567                     0.066567
# 1426                0.066567                     0.066567
# 1427                0.066567                     0.066567
# 1428                0.066567                     0.066567
# 1429                0.066567                     0.066567
#
#       lf_protect_from_wind
# 0                 0.066567
# 1                 0.066567
# 2                 0.066567
# 3                 0.066567
# 4                 0.066567
# ...                    ...
# 1425              0.066567
# 1426              0.066567
# 1427              0.066567
# 1428              0.066567
# 1429              0.066567
#
# [1430 rows x 31 columns]

# %% [markdown]
# ### Save Model and Results

# %%
label_model.save("snorkel_2.pkl")

# %%
df_train.to_csv("results2.csv")
